# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd

# %%
edges = pd.read_csv('UofT_edges.csv')

# %%
edges
# Out:
#           source    target          emt
# 0       983859.0  544485.0   503.807815
# 1       605618.0  362627.0  5157.568486
# 2       323189.0  118238.0   498.628481
# 3       919153.0  983859.0   401.962668
# 4       995748.0  983859.0  5095.458776
# ...          ...       ...          ...
# 466228  743092.0  307628.0  2959.506391
# 466229  420266.0  489593.0   208.011081
# 466230  441447.0  877470.0  2221.199295
# 466231  444883.0  137297.0  1175.932049
# 466232  500103.0  123640.0   100.431608
#
# [466233 rows x 3 columns]

# %%
nodes = pd.read_csv('UofT_nodes.csv')

# %%
nodes
# Out:
#           BIRTH_DT CUST_ADD_DT  OCPTN_NM  RES_CNTRY_CA  CNTRY_OF_INCOME_CA  \
# 0       1981-09-01  2007-07-05      89.0             1                   1
# 1       1994-02-21  2019-05-19      89.0             1                   1
# 2       1962-11-16  2011-08-02      89.0             1                   1
# 3       1998-06-20  2001-08-15      89.0             1                   1
# 4       1942-01-24  2012-10-28      89.0             1                   1
# ...            ...         ...       ...           ...                 ...
# 999995  1939-01-16  1994-03-19     467.0             0                   1
# 999996  1970-12-13  1995-12-22     467.0             0                   1
# 999997  1958-09-09  2010-11-03      65.0             0                   1
# 999998  1983-09-15  2013-01-30     231.0             0                   1
# 999999  1962-01-23  2017-03-07      89.0             0                   0
#
# ...

# %%
occupation = pd.read_csv('UofT_occupation_risk.csv')

# %%
occupation
# Out:
#      code occupation_risk
# 0       0             Low
# 1       1            High
# 2       2             Low
# 3       3             Low
# 4       4             Low
# ..    ...             ...
# 836   836             Low
# 837   837             Low
# 838   838             Low
# 839   839            High
# 840   840            High
#
# [841 rows x 2 columns]

# %%
BadActorList = pd.read_csv('targets.simple.csv')

# %%
BadActorList
# Out:
#                                                   id       schema  \
# 0       acf-00040861bc3f593000830d987d09967ef3503ef1       Person
# 1       acf-0011c68a768924609dc5da5707ac7fa4c4d645a2       Person
# 2       acf-001e7e4c0363f08f1e784c230457960b84a6416f       Person
# 3       acf-002c208139012c8d93b6298358188d7cadafe648       Person
# 4       acf-002cc8fdf8fe41185091a7cb6c598663e7a22eb5       Person
# ...                                              ...          ...
# 258656                                  wbdeb-716880  LegalEntity
# 258657                                  wbdeb-716916  LegalEntity
# 258658                                  wbdeb-717314  LegalEntity
# 258659                                  wbdeb-718111  LegalEntity
# 258660                                   wbdeb-83317  LegalEntity
#
#                                               name  \
# 0                                   Kolyvanov Egor
# 1                          Shipov Sergei Yurievich
# ...

# %% [markdown]
# # Text Processing

# %%
from string import punctuation
import nltk

# %%
print(punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ruiho\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'if', "you're", 'you', 'other', 'such', 'i', 'can', 'this', 'then', 'why', 'wasn', 'shan', 'once', 'ours', "you'd", 'doing', 'll', 'o', 'weren', 'few', 'ain', 'didn', "mustn't", 'isn', 'y', 'himself', 'a', 'into', 'before', 'just', 'them', "should've", 'couldn', 'those', 'be', 'through', 'the', 'out', 'over', 'did', 'which', 'they', 'he', "didn't", 'she', 'we', "it's", 'd', 'between', 't', 'until', 'won', 'by', 'have', 'during', 'ourselves', 'theirs', 'hers', 'while', 'up', "mightn't", "don't", 'don', 'only', 've', 'hasn', "couldn't", 'no', 'to', 'each', 'who', 'been', 'under', 'his', 'what', 'myself', 'of', 's', 'your', 'there', 'when', "shan't", 'these', 'her', "aren't", 'yours', "you'll", 'same', 'about', 'should', 'after', 'that', 'and', 'has', 'needn', "hadn't", 'me', 'aren', "hasn't", 'as', 'it', 'own', 'being', 'am', 'doesn', "wouldn't", 'because', 'from', 'any', 'an', "shouldn't", 'its', 'so', 'my', 'nor', 'than', 'all', 'yourselves', 'herself', 'or', 'their', "you've", "isn
# ...

# %%
def clean_text(text):
    if pd.notnull(text):
        tokens = text.split()
        table = str.maketrans("","", punctuation) #creates a one to one mapping of a character to its translation/replacement
        tokens = [word.translate(table) for word in tokens]
        tokens = [word for word in tokens if word.isalpha()]
        tokens = [word.lower() for word in tokens]
        #tokens = [word for word in tokens if not word in stop_words]
        tokens = [word for word in tokens if len(word) > 1]
        return ' '.join(tokens)
    else:
        return text

# %% [markdown]
# Nodes

# %%
nodes['NAME'] = nodes['NAME'].str.strip()

# %%
nodes.head()
# Out:
#      BIRTH_DT CUST_ADD_DT  OCPTN_NM  RES_CNTRY_CA  CNTRY_OF_INCOME_CA  PEP_FL  \
# 0  1981-09-01  2007-07-05      89.0             1                   1     0.0
# 1  1994-02-21  2019-05-19      89.0             1                   1     0.0
# 2  1962-11-16  2011-08-02      89.0             1                   1     0.0
# 3  1998-06-20  2001-08-15      89.0             1                   1     0.0
# 4  1942-01-24  2012-10-28      89.0             1                   1     0.0
#
#    CASH_SUM_IN  CASH_CNT_IN  CASH_SUM_OUT  CASH_CNT_OUT  WIRES_SUM_IN  \
# 0     2577.785          2.0      2851.663           7.0       70774.0
# 1     3035.502          2.0      4805.997          15.0      282929.0
# 2     1617.571          1.0      3482.809          11.0        7632.0
# 3     3587.042          5.0      1940.943           8.0      149253.0
# 4     1725.524          2.0     13197.169          43.0       92318.0
#
#    WIRES_CNT_IN  WIRES_SUM_OUT  WIRES_CNT_OUT COUNTRY_RISK_INCOME  \
# ...

# %%
nodes['NAME'] = nodes['NAME'].apply(clean_text)

# %%
nodes.head(50)
# Out:
#       BIRTH_DT CUST_ADD_DT  OCPTN_NM  RES_CNTRY_CA  CNTRY_OF_INCOME_CA  \
# 0   1981-09-01  2007-07-05      89.0             1                   1
# 1   1994-02-21  2019-05-19      89.0             1                   1
# 2   1962-11-16  2011-08-02      89.0             1                   1
# 3   1998-06-20  2001-08-15      89.0             1                   1
# 4   1942-01-24  2012-10-28      89.0             1                   1
# 5   1969-05-22  2011-10-03      89.0             1                   1
# 6   1951-03-31  2007-08-07      89.0             1                   1
# 7   1986-08-26  2012-11-26      89.0             1                   1
# 8   2002-06-24  2012-11-28      89.0             1                   1
# 9   1968-01-13  1997-12-23      89.0             1                   1
# 10  1957-11-11  2020-06-24      89.0             1                   1
# 11  2007-06-26  2010-10-14      89.0             1                   1
# ...

# %% [markdown]
# Targets.Simple

# %%
BadActorList['name'] = BadActorList['name'].str.strip()

# %%
BadActorList.head()
# Out:
#                                              id  schema  \
# 0  acf-00040861bc3f593000830d987d09967ef3503ef1  Person
# 1  acf-0011c68a768924609dc5da5707ac7fa4c4d645a2  Person
# 2  acf-001e7e4c0363f08f1e784c230457960b84a6416f  Person
# 3  acf-002c208139012c8d93b6298358188d7cadafe648  Person
# 4  acf-002cc8fdf8fe41185091a7cb6c598663e7a22eb5  Person
#
#                              name                         aliases  birth_date  \
# 0                  Kolyvanov Egor                  Колыванов Егор  1980-11-15
# 1         Shipov Sergei Yurievich            Шипов Сергей Юрьевич  1966-04-17
# 2        Egorov Ivan Mikhailovich          Егоров Иван Михайлович  1961-01-21
# 3  Goreslavsky Alexey Sergeyevich  Гореславский Алексей Сергеевич  1977-07-13
# 4  Samoilova Natalya Vladimirovna  Самойлова Наталья Владимировна  1987-06-24
#
#   countries addresses identifiers sanctions phones emails  \
# 0       NaN       NaN         NaN       NaN    NaN    NaN
# ...

# %%
BadActorList['name'] = BadActorList['name'].apply(clean_text)

# %%
BadActorList.head(50)
# Out:
#                                               id  schema  \
# 0   acf-00040861bc3f593000830d987d09967ef3503ef1  Person
# 1   acf-0011c68a768924609dc5da5707ac7fa4c4d645a2  Person
# 2   acf-001e7e4c0363f08f1e784c230457960b84a6416f  Person
# 3   acf-002c208139012c8d93b6298358188d7cadafe648  Person
# 4   acf-002cc8fdf8fe41185091a7cb6c598663e7a22eb5  Person
# 5   acf-003bf88296087aabb54ccd6db2bcd6928bc893b7  Person
# 6   acf-004166f2e999e45c8ce9f497752a93f24f377198  Person
# 7   acf-004ed1533d17996ba7aa11566f6c56027e2be689  Person
# 8   acf-0062435b173149aba42212a1b16fb393d4a9bd0d  Person
# 9   acf-00641aab3995732925809e5cc203623725c7219f  Person
# 10  acf-0069529d969231bfc2289d9f2d61db89de9bcc82  Person
# 11  acf-00749769d332749ea1839ce82ddad4f18b3187d2  Person
# 12  acf-00776ee02694fb36ef3d6f42fa95ddcdab7f76c8  Person
# 13  acf-008076c876c08dd7c54a05cbec8f82eeaa0af206  Person
# 14  acf-0089427e82e2d014999f7794a7239353425540e2  Person
# ...

# %% [markdown]
# # Customer Dictionary

# %% [markdown]
# # Matching Name&Birthdate

# %% [markdown]
# # Merge Data
