# %%
import pandas as pd
import glob
import os

# %%
from pandas import read_csv

# %%
filename = 'match1.csv'

# %%
match = read_csv(filename, encoding = "ISO-8859-1")

# %%
match
# Out:
#                                       NameBirth matchnum
# 0                        young han park99999999       86
# 1       marcus elliott aka mark bentley19900909       86
# 2                         dean garforth99999999       86
# 3                           helge lindh19761206       62
# 4                        carolyn thomas19650000       86
# ...                                         ...      ...
# 249985        tambieva diana ruslanovna19900806       62
# 249986                     carlos marta19570407       86
# 249987     evelyn pamela falconÃ­ loqui99999999       86
# 249988                      larry potts19480914       65
# 249989                     victor ponte99999999       86
#
# [249990 rows x 2 columns]

# %%
#read the path
cwd = os.path.abspath('')
#list all the files from the directory
file_list = os.listdir(cwd)
file_list
# Out:
# ['match1.csv',
#  'match2.csv',
#  'match3.csv',
#  'match4.csv',
#  '.ipynb_checkpoints',
#  'top100_matchnum.ipynb']

# %%
#list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['match1.csv', 'match2.csv', 'match3.csv', 'match4.csv']

# %%
match_all = pd.DataFrame()
#append all files together
for file in csv_files:
            df_temp = pd.read_csv(file)
            match_all = match_all.append(df_temp, ignore_index=True)
match_all
# Out:
#                                       NameBirth matchnum  \
# 0                        young han park99999999       86
# 1       marcus elliott aka mark bentley19900909       86
# 2                         dean garforth99999999       86
# 3                           helge lindh19761206       62
# 4                        carolyn thomas19650000       86
# ...                                         ...      ...
# 981384                    bauke de haan19390111       67
# 981385                      anthony ada99999999       86
# 981386                bernadette jordan19630407       86
# 981387                         wes hall19370912       59
# 981388   daniel augusto melo lima évora99999999       86
#
#        matchnumchris phillips19691008  67
# 0                                 NaN NaN
# 1                                 NaN NaN
# 2                                 NaN NaN
# 3                                 NaN NaN
# 4                                 NaN NaN
# ...                               ...  ..
# 981384                            NaN NaN
# 981385                            NaN NaN
# 981386                            NaN NaN
# 981387                            NaN NaN
# 981388                            NaN NaN
#
# [981389 rows x 4 columns]

# %% [markdown]
# # Merged_match data

# %%
# Only keep NameBirth and matchnum column in the dataframe
match_all = match_all.loc[:, ('NameBirth', 'matchnum')]
match_all
# Out:
#                                       NameBirth matchnum
# 0                        young han park99999999       86
# 1       marcus elliott aka mark bentley19900909       86
# 2                         dean garforth99999999       86
# 3                           helge lindh19761206       62
# 4                        carolyn thomas19650000       86
# ...                                         ...      ...
# 981384                    bauke de haan19390111       67
# 981385                      anthony ada99999999       86
# 981386                bernadette jordan19630407       86
# 981387                         wes hall19370912       59
# 981388   daniel augusto melo lima évora99999999       86
#
# [981389 rows x 2 columns]

# %%
# delete duplicates
match_all.drop_duplicates(subset="NameBirth",
                     keep='first', inplace=True, ignore_index=False)
match_all
print(match_all)
# Out:
#                                     NameBirth  matchnum
# 0                                   NameBirth  matchnum
# 1      tatiana viktorovna pereverzeva19640620        95
# 2                      alison redford19650307        95
# 3            rahim azizboevich asimov19640816        95
# 4                        david duguid19701008        92
# ...                                       ...       ...
# 75049            qari mohammad yousif19520101        47
# 75050                  qasim alnajjar19580201        45
# 75051            qahiye mohamed ahmed19890000        43
# 75052                   xhavit haliti19560308        43
# 75053       alexey alexeyevich gromov19600531       100
#
# [75054 rows x 2 columns]

# %%
# sort by matchnum
match_all.sort_values(by='matchnum', inplace=False, ascending=False,ignore_index = True)

print(match_all)
# Out:
#                                     NameBirth  matchnum
# 0                                   NameBirth  matchnum
# 1      tatiana viktorovna pereverzeva19640620        95
# 2                      alison redford19650307        95
# 3            rahim azizboevich asimov19640816        95
# 4                        david duguid19701008        92
# ...                                       ...       ...
# 75049            qari mohammad yousif19520101        47
# 75050                  qasim alnajjar19580201        45
# 75051            qahiye mohamed ahmed19890000        43
# 75052                   xhavit haliti19560308        43
# 75053       alexey alexeyevich gromov19600531       100
#
# [75054 rows x 2 columns]

# %%
match_all.head(100)
# Out:
#                                              NameBirth  matchnum
# 1               tatiana viktorovna pereverzeva19640620        95
# 2                               alison redford19650307        95
# 3                     rahim azizboevich asimov19640816        95
# 4                                 david duguid19701008        92
# 5                              robert williams19351231        91
# ..                                                 ...       ...
# 96   neil davidson baron davidson of glen clova1950...        86
# 97                         david woods melling99999999        86
# 98                               alisha ashton99999999        86
# 99                           nicolas gourmelon99999999        86
# 100                              ender karagül99999999        86
#
# [100 rows x 2 columns]

# %%
top50 = match_all.head(50)
top50
# Out:
#                                  NameBirth  matchnum
# 1   tatiana viktorovna pereverzeva19640620        95
# 2                   alison redford19650307        95
# 3         rahim azizboevich asimov19640816        95
# 4                     david duguid19701008        92
# 5                  robert williams19351231        91
# 6                   david anderson19540206        91
# 7                  timothy johnson19591202        91
# 8               ali abdullah saleh19420321        91
# 9                    thomas miller19481209        90
# 10                     nanu cornel99999999        90
# 11                   richard moore19630509        90
# 12                   michael allen19470102        90
# 13                 william martini19470210        89
# 14                 michael brindle19520623        89
# 15                     jason white19721228        89
# 16                     david myers19611231        89
# 17                      john davis19600707        89
# 18                     james white19350513        89
# 19             jose benito cabrera19630706        89
# 20                      david ward19530429        89
# 21                     betty price19520815        89
# 22                      jo johnson19711223        89
# 23                      john sharp19541215        89
# 24                  donald macleod19480924        88
# 25                    robert olson19691201        88
# 26               christopher smith19760401        88
# 27                   andrew bagchi19651210        88
# 28               christopher quinn19671011        88
# 29                         jim ott19470605        88
# 30                   michael colle19450201        88
# 31                    john townend19340612        88
# 32                margaret doherty19510000        88
# 33               christopher jeans19560124        88
# 34              michael richardson19490713        88
# 35                 johan johansson19690711        88
# 36  mikhail alexandrovich afanasov19530605        88
# 37                 tony strickland19700217        87
# 38                 susana martinez19590714        87
# 39                 julia patterson19531201        87
# 40                      james buck19450730        87
# 41                    john freeman19540910        87
# 42                   michael praßl19550915        87
# 43                 robert phillips19560529        87
# 44                 christopher cox19521016        87
# 45                david mackintosh19790402        87
# 46                 mitani hidehiro19760628        86
# 47                    giorgio gaja19391207        86
# 48                   ngo kimcheang99999999        86
# 49                        dam sith99999999        86
# 50        fabian marcelo francioni99999999        86

# %%
match_all['matchnum'].dtype
# the colume ''
# Out:
# dtype('O')

# %%
match_all=match_all.dropna().reset_index(drop=True)
match_all
# Out:
#                                     NameBirth  matchnum
# 0                                   NameBirth  matchnum
# 1      tatiana viktorovna pereverzeva19640620        95
# 2                      alison redford19650307        95
# 3            rahim azizboevich asimov19640816        95
# 4                        david duguid19701008        92
# ...                                       ...       ...
# 75049            qari mohammad yousif19520101        47
# 75050                  qasim alnajjar19580201        45
# 75051            qahiye mohamed ahmed19890000        43
# 75052                   xhavit haliti19560308        43
# 75053       alexey alexeyevich gromov19600531       100
#
# [75054 rows x 2 columns]

# %%
match_all = match_all.iloc[1:]
match_all['matchnum'] = match_all['matchnum'].astype(int)
match_all['matchnum'].dtype
# Out:
# /var/folders/6y/g4gs0h6x6cs229050twxw_zw0000gn/T/ipykernel_39337/2974649464.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   match_all['matchnum'] = match_all['matchnum'].astype(int)
# dtype('int64')

# %%
greater85 = match_all[match_all['matchnum']>85]

# %%
greater85.shape
# Out:
# (10428, 2)
